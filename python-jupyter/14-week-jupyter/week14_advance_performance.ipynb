# %%
#timeit module


import timeit

res1 = timeit.timeit('''
a = [i for i in range(50000)]
for i in a:
    pass
''', number = 100)

res2 = timeit.timeit('''
a = (i for i in range(50000))
for i in a:
    pass
''', number = 100)

print(res1)
print(res2)
# Out:
# 0.20732090000001335
# 0.38272669999969366

# %%
#cProfile & pstats

import cProfile
import pstats
import time
import sys

def to_be_profiled():
    my_list1 = [i**2 for i in range(50000)]

    my_list2 = (i**2 for i in range(100000, 150000))

    sum = 0

    print("my_list1 = {} bytes".format(sys.getsizeof(my_list1)))
    print("my_list2 = {} bytes".format(sys.getsizeof(my_list2)))

    for i in my_list2:
        sum += i
        time.sleep(0.00001)
        my_list1.append(i)
    print(sum)

cProfile.run('to_be_profiled()', 'cprofile_results')

p = pstats.Stats('cprofile_results')
#sort by standard name
p.strip_dirs().sort_stats(-1).print_stats(10)
#sort by function name
p.sort_stats('name').print_stats(10)
#sort by cumulative time in a function
p.sort_stats('cumulative').print_stats(10)
#sort by time spent in a function
p.sort_stats('time').print_stats(10)
# Out:
# my_list1 = 444376 bytes
# my_list2 = 208 bytes
# 791660416675000
# Sat Jun 22 16:03:38 2024    cprofile_results
#
#          150077 function calls in 23.732 seconds
#
#    Ordered by: standard name
#    List reduced from 27 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     50001    0.137    0.000    0.137    0.000 3792526648.py:11(<genexpr>)
#         1    0.459    0.459   23.731   23.731 3792526648.py:8(to_be_profiled)
#         1    0.011    0.011    0.011    0.011 3792526648.py:9(<listcomp>)
#         1    0.001    0.001   23.732   23.732 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 iostream.py:137(_event_pipe)
#         2    0.000    0.000    0.000    0.000 iostream.py:258(schedule)
#         6    0.000    0.000    0.000    0.000 iostream.py:519(_is_master_process)
#         6    0.000    0.000    0.000    0.000 iostream.py:546(_schedule_flush)
#         6    0.000    0.000    0.000    0.000 iostream.py:624(write)
#         2    0.000    0.000    0.000    0.000 socket.py:621(send)
#
#
# Sat Jun 22 16:03:38 2024    cprofile_results
#
#          150077 function calls in 23.732 seconds
#
#    Ordered by: function name
#    List reduced from 27 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   23.732   23.732 {built-in method builtins.exec}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         6    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         2    0.000    0.000    0.000    0.000 {built-in method sys.getsizeof}
#     50000   23.091    0.000   23.091    0.000 {built-in method time.sleep}
#     50001    0.137    0.000    0.137    0.000 3792526648.py:11(<genexpr>)
#         1    0.011    0.011    0.011    0.011 3792526648.py:9(<listcomp>)
#         6    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#
#
# Sat Jun 22 16:03:38 2024    cprofile_results
#
#          150077 function calls in 23.732 seconds
#
#    Ordered by: cumulative time
#    List reduced from 27 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   23.732   23.732 {built-in method builtins.exec}
#         1    0.001    0.001   23.732   23.732 <string>:1(<module>)
#         1    0.459    0.459   23.731   23.731 3792526648.py:8(to_be_profiled)
#     50000   23.091    0.000   23.091    0.000 {built-in method time.sleep}
#     50001    0.137    0.000    0.137    0.000 3792526648.py:11(<genexpr>)
#     50000    0.032    0.000    0.032    0.000 {method 'append' of 'list' objects}
#         1    0.011    0.011    0.011    0.011 3792526648.py:9(<listcomp>)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         6    0.000    0.000    0.000    0.000 iostream.py:624(write)
#         6    0.000    0.000    0.000    0.000 iostream.py:546(_schedule_flush)
#
#
# Sat Jun 22 16:03:38 2024    cprofile_results
#
#          150077 function calls in 23.732 seconds
#
#    Ordered by: internal time
#    List reduced from 27 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     50000   23.091    0.000   23.091    0.000 {built-in method time.sleep}
#         1    0.459    0.459   23.731   23.731 3792526648.py:8(to_be_profiled)
#     50001    0.137    0.000    0.137    0.000 3792526648.py:11(<genexpr>)
#     50000    0.032    0.000    0.032    0.000 {method 'append' of 'list' objects}
#         1    0.011    0.011    0.011    0.011 3792526648.py:9(<listcomp>)
#         1    0.001    0.001   23.732   23.732 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 socket.py:621(send)
#         6    0.000    0.000    0.000    0.000 iostream.py:624(write)
#         1    0.000    0.000   23.732   23.732 {built-in method builtins.exec}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.print}

# %%
#memory_profiler v Line_profiler

import sys
import cProfile
from memory_profiler import profile

@profile()
def mem_to_be_profiled():
    
    my_list1 = [i**2 for i in range(50000)]

    my_list2 = (i**2 for i in range(100000, 150000))

    sum = 0

    print("my_list1 = {} bytes".format(sys.getsizeof(my_list1)))
    print("my_list2 = {} bytes".format(sys.getsizeof(my_list2)))

    for i in my_list2:
        sum += i
        my_list1.append(i)
    print(sum)

mem_to_be_profiled()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 5
#       3 import sys
#       4 import cProfile
# ----> 5 from memory_profiler import profile
#       7 @profile()
#       8 def mem_to_be_profiled():
#      10     my_list1 = [i**2 for i in range(50000)]
#
# ModuleNotFoundError: No module named 'memory_profiler'
